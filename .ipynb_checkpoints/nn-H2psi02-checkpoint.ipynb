# %% [markdown]
# # Simple NN for estimating $H$ ground state, $\psi_0$
# Sam Greydanus. 16 May 2017. MIT License.

# %%
% matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import os, copy, glob
from scipy.sparse.linalg import eigsh
from scipy.sparse import kron, identity

np.random.seed(seed=123) # for reproducibility
ms = torch.manual_seed(123) # for reproducibility

# %% [markdown]
# ## Hyperparameters

# %%
lr = 3e-4
global_step = 0
print_every = 100
save_dir = 'H2psi02_models'
checkpoint_steps = [10,30,100,300,1000,3000,10000] + [250, 500, 1000, 2000, 4000, 16000]
total_steps = max(checkpoint_steps)
d = 2
chi = 4
D_side = d**chi
D_img = D_side**2
D_hidden = 512
batch_size = 16
cost_func = nn.PairwiseDistance() # square and sum to get L2 loss (see train loop)

# %% [markdown]
# ## Dataloader
# Use the same free site as we've been using for DMRG runs. Change the coupling constants `J` and `Jz` randomly, try to estimate change in energy

# %%
sym = lambda M: M + M.T
local_op = lambda d: sym(np.random.randn(d,d))
    
class FreeSite():
    def __init__(self, J=None, Jz=None, rand=False):
        self.length = 1 # length
        self.ops = ops = {}
        self.J = J ; self.Jz = Jz
        
        # build operator dictionary
        ops["H"] = np.zeros((2,2)) # local Hamiltonian np.random.randn(2,2)
        ops["Sz"] = np.array([[0.5, 0], [0, -0.5]]) # z spin (S^z) operator
        ops["Sp"] = np.array([[0.0, 1.0], [0.0, 0.0]]) # raising (S^+) operator
        
        if rand:
            ops["Sz"] = np.random.randn()*np.array([[0, 0.5], [0.5, 0.]]) + np.random.randn()*ops["Sz"]
            ops["Sp"] *= np.random.randn()
    
    def get_dim(self):
        return list(self.ops.values())[0].shape[0] # all ops should have same dimensionality
        
    def enlarge(self, site):
        '''Enlarge block by a single site'''
        
        D1, H1, Sz1, Sp1 = self.get_dim(), self.ops['H'], self.ops['Sz'], self.ops['Sp'] # this block
        D2, H2, Sz2, Sp2 = site.get_dim(), site.ops['H'], site.ops['Sz'], site.ops['Sp'] # another block (ie free site)

        enlarged = copy.deepcopy(self)
        enlarged.length += site.length
        ops = enlarged.ops

        ops['H'] = kron(H1, identity(D2)) + kron(identity(D1), H2) + self.interaction_H(site)
        ops['Sz'] = kron(identity(D1), Sz2)
        ops['Sp'] = kron(identity(D1), Sp2)

        return enlarged
    
    def interaction_H(self, site):
        '''Given another block, returns two-site term in the 
        Hamiltonain that joins the two sites.'''
        Sz1, Sp1 = self.ops["Sz"], self.ops["Sp"] # this block
        Sz2, Sp2 = site.ops["Sz"], site.ops["Sp"] # another block
        
        J = 1.*np.random.randn() if self.J is None else self.J
        Jz = 1.*np.random.randn() if self.Jz is None else self.Jz
        
        join_Sp = (J/2)*(kron(Sp1, Sp2.conjugate().transpose()) + kron(Sp1.conjugate().transpose(), Sp2))
        join_Sz = Jz*kron(Sz1, Sz2)
        return (join_Sp + join_Sz)
    
    def rotate_ops(self, transformation_matrix):
        # rotate and truncate each operator.
        new_ops = {}
        for name, op in self.ops.items():
            new_ops[name] = self.rotate_and_truncate(op, transformation_matrix)
        self.ops = new_ops
    
    @staticmethod
    def rotate_and_truncate(S, O):
        '''Transforms the operator to a new (possibly truncated) basis'''
        return O.conjugate().transpose().dot(S.dot(O)) # eqn 7 in arXiv:cond-mat/0603842v2

# %%
def ham(J, Jz, rand=False):
    sys = FreeSite(J=J, Jz=Jz, rand=rand)
    for _ in range(chi-1):
        fs = FreeSite(J=J, Jz=Jz, rand=rand)
        sys = sys.enlarge(fs)
    return sys.ops['H'].todense()

def next_batch(D, batch_size):
    H_list = [] ; e0_list = [] ; psi0_list = []
    for _ in range(batch_size):
        H = ham(None, None, rand=True)
        e0, psi0 = eigsh(H,k=1, which="SA")
        H_list.append(np.asarray(H).ravel()) ; e0_list.append(e0.ravel()) ; psi0_list.append(psi0.ravel())
    return np.vstack(H_list), np.vstack(e0_list), np.vstack(psi0_list)

# %%
# plot data
f1 = plt.figure(figsize=[12,6])

f1.text(0.5, .92, 'Example training Hamiltonians', ha='center', va='center', fontsize=18)
v = 2
h = 4
H, e0, psi0 = next_batch(D_side, batch_size=batch_size)
sd, mn = np.std(H), np.mean(H)
cl = [mn-3*sd,mn+3*sd]

for i in range(v):
    for j in range(h):
        plot_ix = i*h + j
        curr_plot = v*100 + h*10 + plot_ix+1

        plt.subplot(curr_plot)
        plt.gca().axes.get_xaxis().set_visible(False)
        plt.gca().axes.get_yaxis().set_visible(False)
        H, e0, psi0 = next_batch(D_side, batch_size=1)
        im = plt.imshow(np.reshape(H,[D_side,D_side]))
        plt.clim(*cl)
        
cax = f1.add_axes([0.92, 0.15, 0.02, 0.7])
cb = f1.colorbar(im, cax=cax, orientation='vertical')
cb.set_label('color scale')
    
plt.show() #; f1.savefig('./figures/tph-training-psi0.pdf', bbox_inches='tight')

# %% [markdown]
# ## Build a simple NN model

# %%
# a neural network with three hidden layers
def dot_norm(u):
    m, n = u.size()
    d = u.mm(u.t())
    div_by = torch.sqrt(torch.diag(d))
    v = u / div_by.resize(m, 1).repeat(1,n)
    return v

class SimpleNN3(torch.nn.Module):
    def __init__(self, batch_size, input_dim, h_dim, output_dim):
        super(SimpleNN3, self).__init__()
        self.W1 = nn.Parameter(torch.randn(input_dim, h_dim)*0.075)
        self.b1 = nn.Parameter(torch.randn(h_dim)*0.075)
        self.W2 = nn.Parameter(torch.randn(h_dim, h_dim)*0.075)
        self.b2 = nn.Parameter(torch.randn(h_dim)*0.075)
        self.W3 = nn.Parameter(torch.randn(h_dim, output_dim)*0.075)
        self.b3 = nn.Parameter(torch.randn(output_dim)*0.075)
        self.arch = 'SimpleNN3'

    def forward(self, X, batch_size):
        X = X.resize(batch_size, D_img)
        h1 = F.relu(X.mm(self.W1) + self.b1.repeat(X.size(0), 1))
        h2 = F.relu(h1.mm(self.W2) + self.b2.repeat(X.size(0), 1))
        h3 = h2.mm(self.W3) + self.b3.repeat(X.size(0), 1)
        h3 = dot_norm(h3)
        return h3
    
model = SimpleNN3(batch_size=1, input_dim=D_img, h_dim=D_hidden, output_dim=D_side)

# %%
# global_step = 0
# load_was_success = True # yes, I'm being optimistic
# model_zoo = []
# paths = glob.glob(save_dir + '/*.tar')
# try:
#     for s in paths:
#         checkpoint = torch.load(s)
#         model.load_state_dict(checkpoint['state_dict'])
#         global_step = checkpoint['global_step']
#         model_zoo.append((global_step, copy.deepcopy(model)))
#         print("loaded model: {}".format(s))
#     model_zoo = sorted(model_zoo, key=lambda tup: tup[0])
#     global_step, model = model_zoo[-1]
# except:
#     print("no saved model to load.") ; model_zoo = []
#     load_was_success = False
# else:
#     if len(paths) is 0: print("no saved model to load.")
# Out:
# loaded model: H2psi02_models/model.10.tar
# loaded model: H2psi02_models/model.100.tar
# loaded model: H2psi02_models/model.250.tar
# loaded model: H2psi02_models/model.30.tar
# loaded model: H2psi02_models/model.300.tar
# loaded model: H2psi02_models/model.500.tar

# %% [markdown]
# ## Train model to estimate ground state energies
# Takes ~30 min to train on my MacBook

# %%
b=100
def cost_func(e, psi, H, batch_size):
    e = e.resize(batch_size,1,1)
    psi = psi.resize(batch_size,1,D_side)
    H = H.resize(batch_size,D_side,D_side)
    e0_hat = psi.bmm(H).bmm(torch.transpose(psi, 2,1))
    return torch.mean(e0_hat-e)

np_H, np_e0, np_psi0 = next_batch(D_side, batch_size=b)
real_H = Variable(torch.Tensor(np_H))
real_e0 = Variable(torch.Tensor(np_e0))
real_psi0 = Variable(torch.Tensor(np_psi0))

psi0_hat = model(real_H, batch_size=b) 

print(cost_func(real_e0, real_psi0, real_H, batch_size=b).data.numpy()[0])
print(cost_func(real_e0, psi0_hat, real_H, batch_size=b).data.numpy()[0])

def rand_psi(D_side):
    psi = np.random.rand(1, D_side)
    psi /= np.sqrt(np.dot(psi, psi.T))
    return psi

psis = []
for _ in range(b):
    psis.append(rand_psi(D_side))
rand_psis = Variable(torch.Tensor(np.vstack(psis)))

print(cost_func(real_e0, rand_psis, real_H, batch_size=b).data.numpy()[0])
# Out:
# -1.50502e-08
# 0.0435188
# 1.21967

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
running_loss = None
model_zoo = []
# generic train loop
for global_step in range(global_step, total_steps+global_step+1):
    
    # ======== DISCRIMINATOR STEP ======== #
    # forward
    np_H, np_e0, np_psi0 = next_batch(D_side, batch_size)
    real_H = Variable(torch.Tensor(np_H))
    real_e0 = Variable(torch.Tensor(np_e0))
    real_psi0 = Variable(torch.Tensor(np_psi0))
    
    psi0_hat = model(real_H, batch_size) 

    # backward
#     loss = .5*torch.sum(cost_func(psi0_hat, real_psi0)**2) / batch_size
    loss = cost_func(real_e0, psi0_hat, real_H, batch_size)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    running_loss = loss.data.numpy()[0] if running_loss is None else .99*running_loss + (1-.99)*loss.data.numpy()[0]

    # ======== DISPLAY PROGRESS ======== #
    if global_step % print_every == 0:
        print('step {}: loss: {:.4f}'.format(global_step, running_loss))
    if global_step in checkpoint_steps:
        print('\tstep {}: saved model'.format(global_step))
        torch.save({'state_dict': model.state_dict(),
                   'global_step': global_step}
                   , save_dir + '/model.{}.tar'.format(global_step))
# Out:
# step 1900: loss: -1.1245
# step 2000: loss: -1.1504
# 	step 2000: saved model
# step 2100: loss: -1.1979
# step 2200: loss: -1.2060
# step 2300: loss: -1.2460
# step 2400: loss: -1.1993
# step 2500: loss: -1.1832
# step 2600: loss: -1.1958
# step 2700: loss: -1.2094
# step 2800: loss: -1.2118
# step 2900: loss: -1.1976
# step 3000: loss: -1.1821
# 	step 3000: saved model
# step 3100: loss: -1.1924
# step 3200: loss: -1.2156
# step 3300: loss: -1.2149
# step 3400: loss: -1.2313
# step 3500: loss: -1.2355
# step 3600: loss: -1.2308
# step 3700: loss: -1.1980
# step 3800: loss: -1.1994
# step 3900: loss: -1.2099
# step 4000: loss: -1.1959
# 	step 4000: saved model
# step 4100: loss: -1.1977
# step 4200: loss: -1.2062
# step 4300: loss: -1.2229
# step 4400: loss: -1.2263
# step 4500: loss: -1.2060
# step 4600: loss: -1.1923
# step 4700: loss: -1.1983
# step 4800: loss: -1.2154
# step 4900: loss: -1.2089
# step 5000: loss: -1.2168
# step 5100: loss: -1.2254
# step 5200: loss: -1.2289
# step 5300: loss: -1.2117
# step 5400: loss: -1.2096
# step 5500: loss: -1.2416
# step 5600: loss: -1.2326
# step 5700: loss: -1.2419
# step 5800: loss: -1.2291
# step 5900: loss: -1.2274
# step 6000: loss: -1.2294
# step 6100: loss: -1.2214
# step 6200: loss: -1.2404
# step 6300: loss: -1.2221
# step 6400: loss: -1.2327
# step 6500: loss: -1.2214
# step 6600: loss: -1.2205
# step 6700: loss: -1.2463
# step 6800: loss: -1.2472
# step 6900: loss: -1.2216
# step 7000: loss: -1.2496
# step 7100: loss: -1.2099
# step 7200: loss: -1.2404
# step 7300: loss: -1.2475
# step 7400: loss: -1.2490
# step 7500: loss: -1.2376
# step 7600: loss: -1.2288
# step 7700: loss: -1.2323
# step 7800: loss: -1.2388
# step 7900: loss: -1.2393
# step 8000: loss: -1.2448
# step 8100: loss: -1.2495
# step 8200: loss: -1.2548
# step 8300: loss: -1.2317
# step 8400: loss: -1.2273
# step 8500: loss: -1.2205
# step 8600: loss: -1.2349
# step 8700: loss: -1.2356
# step 8800: loss: -1.2334
# step 8900: loss: -1.2280
# step 9000: loss: -1.2210
# step 9100: loss: -1.2346
# step 9200: loss: -1.2372
# step 9300: loss: -1.2414
# step 9400: loss: -1.2605
# step 9500: loss: -1.2463
# step 9600: loss: -1.2650
# step 9700: loss: -1.2615
# step 9800: loss: -1.2717
# step 9900: loss: -1.2415
# step 10000: loss: -1.2350
# 	step 10000: saved model
# step 10100: loss: -1.2245
# step 10200: loss: -1.2255
# step 10300: loss: -1.2089
# step 10400: loss: -1.2477
# step 10500: loss: -1.2231
# step 10600: loss: -1.2522
# step 10700: loss: -1.2376
# step 10800: loss: -1.2112
# step 10900: loss: -1.2317
# step 11000: loss: -1.2728
# step 11100: loss: -1.2474
# step 11200: loss: -1.2439
# step 11300: loss: -1.2394
# step 11400: loss: -1.2420
# step 11500: loss: -1.2594
# step 11600: loss: -1.2672
# step 11700: loss: -1.2423
# step 11800: loss: -1.2224
# step 11900: loss: -1.2305
# step 12000: loss: -1.2385
# step 12100: loss: -1.2074
# step 12200: loss: -1.2290
# step 12300: loss: -1.2481
# step 12400: loss: -1.2431
# step 12500: loss: -1.2341
# step 12600: loss: -1.2339
# step 12700: loss: -1.2119
# step 12800: loss: -1.2420
# step 12900: loss: -1.2488
# step 13000: loss: -1.2291
# step 13100: loss: -1.2649
# step 13200: loss: -1.2644
# step 13300: loss: -1.2723
# step 13400: loss: -1.2701
# step 13500: loss: -1.2620
# step 13600: loss: -1.2723
# step 13700: loss: -1.2654
# step 13800: loss: -1.2610
# step 13900: loss: -1.2640
# step 14000: loss: -1.2715
# step 14100: loss: -1.2569
# step 14200: loss: -1.2497
# step 14300: loss: -1.2313
# step 14400: loss: -1.2727
# step 14500: loss: -1.2756
# step 14600: loss: -1.2592
# step 14700: loss: -1.2540
# step 14800: loss: -1.2196
# step 14900: loss: -1.2530
# step 15000: loss: -1.2354
# step 15100: loss: -1.2258
# step 15200: loss: -1.2070
# step 15300: loss: -1.2548
# step 15400: loss: -1.2520
# step 15500: loss: -1.2820
# step 15600: loss: -1.2612
# step 15700: loss: -1.2367
# step 15800: loss: -1.2632
# step 15900: loss: -1.2585
# step 16000: loss: -1.2548
# 	step 16000: saved model
# step 16100: loss: -1.2625
# step 16200: loss: -1.2634
# step 16300: loss: -1.2293
# step 16400: loss: -1.2649
# step 16500: loss: -1.2761
# step 16600: loss: -1.2449
# step 16700: loss: -1.2359
# step 16800: loss: -1.2563
# step 16900: loss: -1.2446
# step 17000: loss: -1.2409
# step 17100: loss: -1.2297
# step 17200: loss: -1.2585
# step 17300: loss: -1.2356
# step 17400: loss: -1.2565
# step 17500: loss: -1.2581
# step 17600: loss: -1.2648
# step 17700: loss: -1.2615
# step 17800: loss: -1.2682

# %%
global_step = 0
load_was_success = True # yes, I'm being optimistic
model_zoo = []
paths = glob.glob(save_dir + '/*.tar')

try:
    for s in paths:
        checkpoint = torch.load(s)
        model.load_state_dict(checkpoint['state_dict'])
        global_step = checkpoint['global_step']
        model_zoo.append((global_step, copy.deepcopy(model)))
        print("loaded model: {}".format(s))
    model_zoo = sorted(model_zoo, key=lambda tup: tup[0])
    global_step, model = model_zoo[-1]
except:
    print("no saved model to load.") ; model_zoo = []
    load_was_success = False
else:
    if len(paths) is 0: print("no saved model to load.")

# %%
steps_to_plot = [250, 500, 1000, 2000, 4000, 16000]
temp = []
for (step, model) in model_zoo:
    if step in steps_to_plot:
        temp.append((step, model))
model_zoo = temp

# %%
b = 8
np_H, np_e0, np_psi0 = next_batch(D_side, batch_size=b)
real_H = Variable(torch.Tensor(np_H))
real_psi0 = Variable(torch.Tensor(np_psi0))
psi0_hat = model(real_H, batch_size=b) 

np_real_psi0 = real_psi0.data.numpy()
np_psi0_hat = psi0_hat.data.numpy()

sd, mn = np.std(np_real_psi0), np.mean(np_real_psi0)
cl = [mn-2*sd,mn+2*sd]
use_cl = True
if use_cl: print(cl)

f2 = plt.figure(figsize=[16,8])
plt.subplot(211)
plt.imshow(np_real_psi0.T) ; plt.title('true $\psi_0$')
if use_cl: plt.clim(*cl)
plt.subplot(212)
im = plt.imshow(np_psi0_hat.T) ; plt.title('Predicted $\psi_0$')
if use_cl: plt.clim(*cl)

cax = f2.add_axes([0.8, 0.15, 0.02, 0.7])
cb = f2.colorbar(im, cax=cax, orientation='vertical')
cb.set_label('color scale')

plt.show()
# Out:
# [-0.48281020857393742, 0.51510207913815975]

# %%
b = 1
np_H, np_e0, np_psi0 = next_batch(D_side, batch_size=b)
real_H = Variable(torch.Tensor(np_H))
real_psi0 = Variable(torch.Tensor(np_psi0))
psi0_hat = model(real_H, batch_size=b) 

np_real_psi0 = real_psi0.data.numpy()
np_psi0_hat = psi0_hat.data.numpy()

sd, mn = np.std(np_real_psi0), np.mean(np_real_psi0)
cl = [mn-2*sd,mn+2*sd]
use_cl = True
if use_cl: print(cl)

f2 = plt.figure(figsize=[8,3])
plt.subplot(211)
plt.imshow(np_real_psi0) ; plt.title('exact $\psi$')
if use_cl: plt.clim(*cl)
plt.subplot(212)
im = plt.imshow(np_psi0_hat) ; plt.title('estimated $\psi$')
if use_cl: plt.clim(*cl)

cax = f2.add_axes([0.95, 0.15, 0.02, 0.7])
cb = f2.colorbar(im, cax=cax, orientation='vertical')
cb.set_label('color scale')

plt.show() ; f2.savefig('./figures/H2psi0.pdf', bbox_inches='tight')

# %%
# '''fancy cost function. Rewards network for choosing e'vecs that
# produce values of H*psi/psi that have low means and stdevs'''
# def cost_func(psi0_hat, H, e0, psi0):
#     r1 = 1 ; r2 = 1 ; r3 = 1 # coupling stengths
#     psi_cost = .5*torch.sum((psi0_hat - psi0)**2)/batch_size
    
#     H_ = H.resize(batch_size,D_side, D_side)
#     e0_ = e0.resize(batch_size,1,1).repeat(1,D_side,1)
#     psi0_hat_ = psi0_hat.resize(batch_size, D_side, 1)
#     e0s = torch.bmm(H_, psi0_hat_) / psi0_hat_
#     e_diff = torch.mean(torch.abs(e0s-e0_)) / batch_size
#     e_diff_std = torch.mean(torch.std(e0s-e0_,1))
#     return r1*psi_cost + r2*e_diff + r3*e_diff_std

# %% [markdown]
# ## Measure mean % error

# %%
mpe = 0 ; me = 0
k = 1000
for i in range(k):
    np_H, np_e0, np_psi0 = next_batch(D_side, batch_size=1)
    real_H = Variable(torch.Tensor(np_H))
    psi0_hat = model(real_H, batch_size=1)
    np_psi0_hat = psi0_hat.data.numpy()
    me += (1./k)*np.mean(np.abs(np_psi0 - np_psi0_hat))
    mpe += (1./k)*np.mean(np.abs(np_psi0 - np_psi0_hat))/1.*100
print("mean error: {:.4f} \nmean percent error: {:.4f}%".format(me, mpe))
